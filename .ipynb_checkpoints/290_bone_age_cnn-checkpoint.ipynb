# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import time
import random
import os
from PIL import Image
from PIL import Image, ImageDraw
import cv2
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import torchvision.transforms as transforms
from torchvision import utils
import torch.optim as optim
from torch.optim import Adam
import torch.nn.init as init
import torchvision.transforms.functional as TF

# %% [markdown]
# ### Import the dataset and find the path of images

# %%
train_df = pd.read_csv('train.csv')

# %%
test_df = pd.read_csv('test.csv')

# %%
# check for duplicates, no duplicates found
train_df[train_df.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [id, boneage, male]
# Index: []

# %%
# check for duplicates, no duplicates found
test_df[test_df.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [id, male, boneage]
# Index: []

# %%
# image file directory
img_dir = r'C:\Users\stron\Desktop\290 Project\Bone Age Training Set'
test_img_dir = r'C:\Users\stron\Desktop\290 Project\Bone Age Test Set'

# %%
def return_filepath(name, folder=img_dir):
    path = os.path.join(folder, f'{name}.png')
    return path

# %%
# find the file path for each image
train_df['image_path'] = train_df.iloc[:, 0].apply(lambda x: return_filepath(x))
test_df['image_path'] = test_df.iloc[:, 0].apply(lambda x: return_filepath(x, test_img_dir))

# %%
train_df['male'] = train_df['male'].astype(int)
test_df['male'] = test_df['male'].astype(int)

# %%
train_df.head(10)
# Out:
#      id  boneage  male                                         image_path
# 0  1377      180     0  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 1  1378       12     0  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 2  1379       94     0  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 3  1380      120     1  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 4  1381       82     0  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 5  1382      138     1  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 6  1383      150     1  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 7  1384      156     1  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 8  1385       36     1  C:\Users\stron\Desktop\290 Project\Bone Age Tr...
# 9  1387      138     1  C:\Users\stron\Desktop\290 Project\Bone Age Tr...

# %%
test_df.head(5)
# Out:
#      id  male  boneage                                         image_path
# 0  1386     0       30  C:\Users\stron\Desktop\290 Project\Bone Age Te...
# 1  1392     1      162  C:\Users\stron\Desktop\290 Project\Bone Age Te...
# 2  1397     0       18  C:\Users\stron\Desktop\290 Project\Bone Age Te...
# 3  1401     0      132  C:\Users\stron\Desktop\290 Project\Bone Age Te...
# 4  1410     1       57  C:\Users\stron\Desktop\290 Project\Bone Age Te...

# %%
class RadiologyDataset(Dataset):
    
    def __init__(self, images_filepaths, male_features, bone_ages, transform):
        self.images_filepaths = images_filepaths
        self.male_features = male_features
        self.bone_ages = bone_ages
        self.transform = transform

    def __len__(self):
        return len(self.images_filepaths)

    def __getitem__(self, idx):
        image_filepath = self.images_filepaths[idx]        
        img_cv2 = cv2.imread(image_filepath)
        image = cv2.cvtColor(img_cv2, cv2.COLOR_BGR2RGB) # only this method read the image as black/white
        image = self.transform(image)
        male = self.male_features[idx]
        label = torch.tensor(self.bone_ages[idx])
        return image, male, label

# %%
# tranformation that converts images into tensors
img_transformer = transforms.Compose([transforms.ToTensor(),
                                      transforms.Resize((512,512)),
                                      transforms.RandomHorizontalFlip(p=0.5),
                                      #transforms.RandomVerticalFlip(p=0.5),
                                      #transforms.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=10),
                                     ])

# %%
# train df
X_train = train_df['image_path']
X_train_male = train_df['male'] # important feature in predicting bone age
y_train = train_df['boneage'] # do we need to normalize the bone age?

# %%
# train
train_dataset = RadiologyDataset(
    images_filepaths = X_train.values,
    male_features = X_train_male.values,
    bone_ages = y_train.values,
    transform = img_transformer
)

# %%
# test df
X_test = test_df['image_path']
X_test_male = test_df['male'] # important feature in predicting bone age
y_test = test_df['boneage']

# %%
# test
test_dataset = RadiologyDataset(
    images_filepaths = X_test.values,
    male_features = X_test_male.values,
    bone_ages = y_test.values,
    transform = img_transformer
)

# %%
# an example tensor
img, male, label = train_dataset[9]
print(img.shape,torch.min(img),torch.max(img))
# Out:
# torch.Size([3, 512, 512]) tensor(1.5947e-05) tensor(0.9938)

# %%
# check the test set
img, male, label = test_dataset[9]
print(img.shape,torch.min(img),torch.max(img))
# Out:
# torch.Size([3, 512, 512]) tensor(0.1654) tensor(0.9277)

# %%
def plot_img(train_dataset_p = train_dataset, inline=5):
    plt.figure(figsize=(20,10))
    j = 0
    for i in range(inline):
        image, dense, label = train_dataset_p[j]
        plt.subplot(1, inline, i%inline+1)
        plt.axis('off')
        plt.imshow(image.permute(2, 1, 0))
        plt.title(f'Bone Age: {label}')
        j = j + 1

# %%
plot_img(inline = 5)

# %%
# train validation split
len_img = len(train_dataset)
len_train = len_img - 700
len_val = 700

# split the tensor
train_dataset, val_dataset = random_split(train_dataset, [len_train, len_val])

print("train dataset size:", len(train_dataset))
print("validation dataset size:", len(val_dataset))
# Out:
# train dataset size: 11911
# validation dataset size: 700

# %%
# create dataloaders
train_val_batch_size = 32
test_batch_size = 32
train_loader = DataLoader(train_dataset, batch_size = train_val_batch_size, shuffle = True, num_workers = 0)
val_loader = DataLoader(val_dataset, batch_size = train_val_batch_size, num_workers = 0)

# %%
test_loader = DataLoader(test_dataset, batch_size = test_batch_size, num_workers = 0)

# %% [markdown]
# ## Define the neural network

# %%
lr = 0.001 # learning rate

# Define the neural network 
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(64*64*64+1, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 1)

    def forward(self, x, male):
        x = self.pool1(nn.functional.relu(self.conv1(x)))
        x = self.pool2(nn.functional.relu(self.conv2(x)))
        x = self.pool3(nn.functional.relu(self.conv3(x)))
        x = x.view(-1, 64*64*64) # reshape
        x = torch.cat([x, male.unsqueeze(1)], dim=1)
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = nn.functional.relu(self.fc3(x))
        x = nn.functional.relu(self.fc4(x))
        x = nn.functional.relu(self.fc5(x))
        return x

model = Network()

# initialization
for name, param in model.named_parameters():
    if 'weight' in name:
        init.kaiming_uniform_(param)
    elif 'bias' in name:
        init.constant_(param, 0.01)

# %%
# Define your execution device 
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
# Out:
# Network(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=262145, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
# function to save the model
def model_save():
    path = './nn_model_290_1.pth'
    torch.save(model.state_dict(), path)

# %%
# loss function L2
loss_fn = nn.MSELoss()
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=0.0001)

# %% [markdown]
# ## Training Loop

# %%
epochs = 100
min_valid_loss = np.inf
tic = time.time()

for epoch in range(1, epochs+1):
    train_loss = 0.0
    for data in train_loader:
        image, male, labels = data
        image = image.cuda()
        male = male.cuda()
        labels = labels.unsqueeze(1).float()
        labels = labels.cuda()
    
        optimizer.zero_grad() # zero the parameter gradients
        target = model(image, male)
        loss = loss_fn(target, labels)
        loss.backward() # backpropagate the loss
        optimizer.step() # adjust the parameters
        train_loss += loss.item() # track the loss value
    
    # calculate the training loss value
    train_loss_value = train_loss / len(train_loader)
     
    valid_loss = 0.0
    model.eval()
    preds = []
    y_actual = []
    for data in val_loader:
        image, male, labels = data
        image = image.cuda()
        male = male.cuda()
        labels = labels.unsqueeze(1).float()
        labels = labels.cuda()
        
        target = model(image, male)
        loss = loss_fn(target,labels)
        valid_loss += loss.item()
        
        with torch.no_grad():
            output = model(image, male)
            preds.append(output.cpu())
            y_actual.append(labels.cpu())
        
    # calculate the validation loss value
    val_loss_value = valid_loss / len(val_loader)
    
    # calculate the validation mae
    preds = torch.cat(preds)
    preds_processed = np.array(preds.reshape(-1))
    y_actual = torch.cat(y_actual)
    y_actual_processed = np.array(y_actual.reshape(-1))
    val_mae = mean_absolute_error(y_actual_processed, preds_processed)
    
    # Save the model
    if min_valid_loss > valid_loss:
        min_valid_loss = valid_loss
        model_save()
        
    print('Completed training batch', epoch, 'Training Loss is: %.4f' %train_loss_value, 'Validation Loss is: %.4f' %val_loss_value, 'Validation MAE is: %.4f' %val_mae)

tac = time.time()
print('Run time: ', round((tac - tic) / 60, 2), ' min')
# Out:
# Completed training batch 1 Training Loss is: 1867.9072 Validation Loss is: 1387.6741 Validation MAE is: 29.0375
# Completed training batch 2 Training Loss is: 1242.6993 Validation Loss is: 1029.8814 Validation MAE is: 25.2130
# Completed training batch 3 Training Loss is: 1013.1210 Validation Loss is: 948.3908 Validation MAE is: 24.2544
# Completed training batch 4 Training Loss is: 846.6702 Validation Loss is: 906.6166 Validation MAE is: 23.6294
# Completed training batch 5 Training Loss is: 705.1726 Validation Loss is: 774.2771 Validation MAE is: 21.3678
# Completed training batch 6 Training Loss is: 559.4883 Validation Loss is: 705.2031 Validation MAE is: 20.2415
# Completed training batch 7 Training Loss is: 439.0296 Validation Loss is: 866.6789 Validation MAE is: 23.2985
# Completed training batch 8 Training Loss is: 339.5925 Validation Loss is: 636.6428 Validation MAE is: 18.5991
# Completed training batch 9 Training Loss is: 248.5684 Validation Loss is: 594.9204 Validation MAE is: 18.0390
# Completed training batch 10 Training Loss is: 202.6246 Validation Loss is: 619.1000 Validation MAE is: 18.6673
# Completed training batch 11 Training Loss is: 165.4188 Validation Loss is: 541.9477 Validation MAE is: 16.9565
# Completed training batch 12 Training Loss is: 127.9303 Validation Loss is: 557.8114 Validation MAE is: 17.6037
# Completed training batch 13 Training Loss is: 108.1442 Validation Loss is: 661.7839 Validation MAE is: 19.9994
# Completed training batch 14 Training Loss is: 88.2830 Validation Loss is: 531.2027 Validation MAE is: 17.5555
# Completed training batch 15 Training Loss is: 82.6086 Validation Loss is: 599.1541 Validation MAE is: 18.0618
# Completed training batch 16 Training Loss is: 76.8654 Validation Loss is: 623.4518 Validation MAE is: 18.2812
# Completed training batch 77 Training Loss is: 13.6234 Validation Loss is: 402.4586 Validation MAE is: 14.7073
# Completed training batch 78 Training Loss is: 13.9821 Validation Loss is: 381.4711 Validation MAE is: 14.4136
# Completed training batch 79 Training Loss is: 14.5553 Validation Loss is: 409.0178 Validation MAE is: 14.8278
# Completed training batch 80 Training Loss is: 14.9489 Validation Loss is: 449.0926 Validation MAE is: 15.5060
# Completed training batch 81 Training Loss is: 14.8457 Validation Loss is: 411.5276 Validation MAE is: 14.7875
# Completed training batch 82 Training Loss is: 14.4962 Validation Loss is: 401.8014 Validation MAE is: 14.5796
# Completed training batch 83 Training Loss is: 13.0368 Validation Loss is: 403.5718 Validation MAE is: 14.5596
# Completed training batch 84 Training Loss is: 13.3035 Validation Loss is: 389.6027 Validation MAE is: 14.2837
# Completed training batch 85 Training Loss is: 13.8830 Validation Loss is: 390.0679 Validation MAE is: 14.4024
# Completed training batch 86 Training Loss is: 14.0252 Validation Loss is: 397.7643 Validation MAE is: 14.6358
# Completed training batch 87 Training Loss is: 13.9662 Validation Loss is: 378.6379 Validation MAE is: 14.2557
# Completed training batch 88 Training Loss is: 13.8508 Validation Loss is: 384.5082 Validation MAE is: 14.3006
# Completed training batch 89 Training Loss is: 12.5114 Validation Loss is: 420.1968 Validation MAE is: 14.9113
# Completed training batch 90 Training Loss is: 12.7330 Validation Loss is: 367.6546 Validation MAE is: 14.0510
# Completed training batch 91 Training Loss is: 14.3730 Validation Loss is: 393.5103 Validation MAE is: 14.4284
# Completed training batch 92 Training Loss is: 11.9773 Validation Loss is: 389.7031 Validation MAE is: 14.3952
# Completed training batch 93 Training Loss is: 12.9270 Validation Loss is: 364.7575 Validation MAE is: 14.1262
# Completed training batch 94 Training Loss is: 11.4060 Validation Loss is: 381.8227 Validation MAE is: 14.3845
# Completed training batch 95 Training Loss is: 11.3733 Validation Loss is: 396.9038 Validation MAE is: 14.3509
# Completed training batch 96 Training Loss is: 11.0514 Validation Loss is: 410.7363 Validation MAE is: 14.8665
# Completed training batch 97 Training Loss is: 11.4137 Validation Loss is: 399.1267 Validation MAE is: 14.5687
# Completed training batch 98 Training Loss is: 11.4958 Validation Loss is: 410.6809 Validation MAE is: 14.5584
# Completed training batch 99 Training Loss is: 11.3684 Validation Loss is: 381.2121 Validation MAE is: 14.1983
# Completed training batch 100 Training Loss is: 11.2961 Validation Loss is: 374.7776 Validation MAE is: 14.2952
# Run time:  633.2  min

# %% [markdown]
# ## Make predictions on the test dataset

# %%
model.eval()

preds = []
for data in tqdm(test_loader):
    image, male, labels = data
    image = image.cuda()
    male = male.cuda()
    labels = labels.cuda()
    
    with torch.no_grad():
        output = model(image, male)
        preds.append(output.cpu())
# Out:
# 100%|██████████| 45/45 [00:43<00:00,  1.05it/s]

# %%
preds = torch.cat(preds)
print(preds.shape)
preds_processed = np.array(preds.reshape(-1))
print(len(preds_processed))
# Out:
# torch.Size([1425, 1])
# 1425

# %%
print('MAE: ', mean_absolute_error(y_test, preds_processed))
# Out:
# MAE:  15.44310825816372
